# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append("../")
from Data.Data import DiffractionDataset

# %%
#Data for Bravais Lattice Classification
Bravais_data=DiffractionDataset("../Data/BravaisLattice_Data.pt", categorical='Bravais Lattice')
#Data for Space Group Classification
Space_group=DiffractionDataset("../Data/SpaceGroup_Data.pt", categorical='Space Group')

# %%
#Change index to plot other values.
Bravais_data.plot(idx=0);

# %%
#Change index to plot other values
Space_group.plot(idx=1);
